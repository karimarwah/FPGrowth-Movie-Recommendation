# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-52b5ceba-0221-496a-a6a5-9e962623e934" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52b5ceba-0221-496a-a6a5-9e962623e934">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving movie.csv to movie.csv

# %%
import pandas as pd
import numpy as np
import random

# %%
data=pd.read_csv('movie.csv')

# %%
data.fillna(value=0,axis=1,inplace=True)
data.head()
# Out:
#    color      director_name  ...  aspect_ratio  movie_facebook_likes
# 0  Color      James Cameron  ...          1.78                 33000
# 1  Color     Gore Verbinski  ...          2.35                     0
# 2  Color         Sam Mendes  ...          2.35                 85000
# 3  Color  Christopher Nolan  ...          2.35                164000
# 4      0        Doug Walker  ...          0.00                     0
#
# [5 rows x 28 columns]

# %%
data.drop(['duration', 'actor_3_facebook_likes', 'actor_2_facebook_likes', 'actor_1_facebook_likes', 'movie_imdb_link' , 'country', 'movie_facebook_likes', 'budget', 'title_year'], axis=1, inplace=True)

# %%
data.drop(['aspect_ratio','color', 'num_critic_for_reviews', 'director_facebook_likes', 'gross', 'num_voted_users' , 'cast_total_facebook_likes', 'facenumber_in_poster', 'plot_keywords', 'num_user_for_reviews', 'language', 'content_rating'],axis=1,inplace=True)

# %%
data.shape
# Out:
# (5043, 7)

# %%
data.head()
# Out:
#        director_name      actor_2_name  ...          actor_3_name imdb_score
# 0      James Cameron  Joel David Moore  ...             Wes Studi        7.9
# 1     Gore Verbinski     Orlando Bloom  ...        Jack Davenport        7.1
# 2         Sam Mendes      Rory Kinnear  ...      Stephanie Sigman        6.8
# 3  Christopher Nolan    Christian Bale  ...  Joseph Gordon-Levitt        8.5
# 4        Doug Walker        Rob Walker  ...                     0        7.1
#
# [5 rows x 7 columns]

# %%
DatasetMovie=[]
for x in range(0,1000):
    DatasetMovie.append([str(data.values[x,y]) for y in range(0,7)])

# %%
DatasetMovie[:1]
# Out:
# [['James Cameron',
#   'Joel David Moore',
#   'Action|Adventure|Fantasy|Sci-Fi',
#   'CCH Pounder',
#   'Avatar\xa0',
#   'Wes Studi',
#   '7.9']]

# %%
def getReccomendation(r):
    for x in range(0,1000):
      if (DatasetMovie)[x][3] == r[3] or (DatasetMovie)[x][2] == r[0] or (DatasetMovie)[x][2] == r[2]:
        if DatasetMovie[x][4] != r[4]:
          return DatasetMovie[x]
        else:
          return random.choice(DatasetMovie)
      else: 
        return random.choice(DatasetMovie)

# %%
movieRiwayat=[]
userRiwayat=[]
for x in range(0,1000):
    firtsMovie = (random.choice(DatasetMovie))
    userRiwayat.append([])
    movieRiwayat.append([])
    movieRiwayat[x].append(getReccomendation(firtsMovie))
    for y in range(0,30):
      movieRiwayat[x].append(getReccomendation(movieRiwayat[x][y]))
      userRiwayat[x].append(movieRiwayat[x][y][4].replace(u'\xa0', u''))

# %%
userRiwayat[:1]
# Out:
# [['Hudson Hawk',
#   'Pacific Rim',
#   'Transformers: Age of Extinction',
#   'The Last Witch Hunter',
#   'The Sentinel',
#   'Blades of Glory',
#   'The Shaggy Dog',
#   'Treasure Planet',
#   'The Last Legion',
#   'Harry Potter and the Deathly Hallows: Part I',
#   'Turbo',
#   'After Earth',
#   'Spectre',
#   'The Other Guys',
#   'War of the Worlds',
#   'Arthur and the Invisibles',
#   'Walking with Dinosaurs 3D',
#   'Stargate SG-1',
#   'Wall Street: Money Never Sleeps',
#   'The Flintstones in Viva Rock Vegas',
#   'Starsky & Hutch',
#   'Life of Pi',
#   'Fast Five',
#   'Goosebumps',
#   'Charlie and the Chocolate Factory',
#   'Quantum of Solace',
#   'Inside Out',
#   'A.I. Artificial Intelligence',
#   'Ted 2',
#   'The Haunting']]

# %%
pip install pyfpgrowth
# Out:
# Collecting pyfpgrowth
#   Downloading https://files.pythonhosted.org/packages/d2/4c/8b7cd90b4118ff0286d6584909b99e1ca5642bdc9072fa5a8dd361c864a0/pyfpgrowth-1.0.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 12.2MB/s
# Building wheels for collected packages: pyfpgrowth
#   Building wheel for pyfpgrowth (setup.py) ... done
#   Created wheel for pyfpgrowth: filename=pyfpgrowth-1.0-py2.py3-none-any.whl size=5479 sha256=b1d96231bc6179b588841b130baf5915963bda1a25502acebb437d746ca5893d
#   Stored in directory: /root/.cache/pip/wheels/3b/3f/0d/a04bb8b17887c1eca7d0f1a48d4aa0c09c96eb221ff7fa56c1
# Successfully built pyfpgrowth
# Installing collected packages: pyfpgrowth
# Successfully installed pyfpgrowth-1.0

# %%
import pyfpgrowth

# %%
transactions = userRiwayat
sup = 0.004
  # float(input("Enter support %: "))
patterns = pyfpgrowth.find_frequent_patterns(transactions,int(len(transactions)*sup))
for k,v in patterns.items():
  print(k,v)
print(len(patterns))
rules = pyfpgrowth.generate_association_rules(patterns, 0.2)
print(rules)
print(len(rules))
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# ('Bewitched', 'The Pacifier', 'Zodiac') 4
# ('Bewitched', 'The Pacifier', 'The Phantom of the Opera', 'Zodiac') 4
# ('2 Guns', 'The Pacifier') 4
# ('The Avengers', 'The Pacifier') 4
# ('Big Hero 6', 'The Pacifier') 4
# ('The Hateful Eight', 'The Pacifier') 4
# ('The Pacifier', 'War Horse') 4
# ('The Pacifier', 'War Horse', 'Zodiac') 6
# ('The Pacifier', 'The Phantom of the Opera', 'War Horse') 4
# ('The Pacifier', 'The Phantom of the Opera', 'War Horse', 'Zodiac') 4
# ('How Do You Know', 'The Pacifier') 5
# ('How Do You Know', 'The Pacifier', 'The Phantom of the Opera') 4
# ('How Do You Know', 'The Pacifier', 'Zodiac') 4
# ('How Do You Know', 'The Pacifier', 'The Phantom of the Opera', 'Zodiac') 4
# ('The Pacifier', 'The Phantom of the Opera') 6
# ('The Pacifier', 'The Phantom of the Opera', 'Zodiac') 8
# ('The Pacifier', 'Zodiac') 7
# ('Avatar', 'The Pacifier') 8
# ('Inside Man', 'World War Z') 4
# ('Inside Man', 'The Day the Earth Stood Still') 4
# ('Indiana Jones and the Kingdom of the Crystal Skull', 'Inside Man') 4
# ('Bad Boys II', 'Inside Man') 4
# ('Avatar', 'Inside Man') 4
# ('Avatar', 'Bad Boys II', 'Inside Man') 4
# ('Harry Potter and the Half-Blood Prince', 'Inside Man') 4
# ('Abraham Lincoln: Vampire Hunter', 'Inside Man') 4
# ('Inside Man', 'The Little Prince') 4
# ('Cats & Dogs: The Revenge of Kitty Galore', 'Inside Man') 4
# ('Collateral', 'Inside Man') 4
# ('Inside Man', 'The Legend of Tarzan') 4
# ('Enchanted', 'Inside Man') 4
# ('Enchanted', 'Harry Potter and the Half-Blood Prince', 'Inside Man') 4
# ('Inside Man', 'The 13th Warrior') 5
# ('Kingdom of Heaven', 'The Expendables') 4
# ('Kingdom of Heaven', 'The Postman') 4
# ('Kingdom of Heaven', 'Seven Pounds') 4
# ('Green Lantern', 'Kingdom of Heaven') 4
# ('Kingdom of Heaven', 'Over the Hedge') 4
# ('Driven', 'Kingdom of Heaven') 4
# ('Enchanted', 'Kingdom of Heaven') 4
# ('G.I. Joe: Retaliation', 'Kingdom of Heaven') 5
# ('Chicken Little', 'Kingdom of Heaven') 5
# ('Kingdom of Heaven', 'The Legend of Bagger Vance') 5
# ('Hotel for Dogs', 'Kingdom of Heaven') 6
# ('Avatar', 'Kingdom of Heaven') 7
# ('Hairspray', 'Jack the Giant Slayer') 4
# ('Disclosure', 'Hairspray') 4
# ('Bewitched', 'Hairspray') 4
# ('Collateral', 'Hairspray') 4
# ('Hairspray', 'The Replacements') 4
# ('Hairspray', 'The Fan') 4
# ('Hairspray', 'True Lies') 4
# ('Hairspray', 'The Curious Case of Benjamin Button') 4
# ('Hairspray', 'Sahara') 4
# ('Hairspray', 'The Terminal') 5
# ('Hairspray', 'The Time Machine') 5
# ('Avatar', 'Hairspray') 7
# ('Pocahontas', 'The Legend of Tarzan') 4
# ('Cinderella', 'Pocahontas') 4
# ('Pocahontas', 'Transformers: Revenge of the Fallen') 4
# ('Captain Phillips', 'Pocahontas') 4
# ('Mighty Joe Young', 'Pocahontas') 4
# ('Pocahontas', 'The Twilight Saga: Eclipse') 4
# ('Pocahontas', 'The Hunger Games: Mockingjay - Part 1') 4
# ('Dinner for Schmucks', 'Pocahontas') 4
# ('Pocahontas', 'Proof of Life') 4
# ('Avatar', 'Pocahontas') 6
# ("Something's Gotta Give", 'The Scorch Trials') 4
# ('Jurassic World', "Something's Gotta Give") 4
# ('Analyze That', "Something's Gotta Give") 4
# ("Something's Gotta Give", 'Treasure Planet') 4
# ('Hercules', "Something's Gotta Give") 4
# ('Snake Eyes', "Something's Gotta Give") 4
# ('Littleman', "Something's Gotta Give") 4
# ("Something's Gotta Give", 'Spy Game') 4
# ('Avatar', "Something's Gotta Give") 6
# ('Alice Through the Looking Glass', 'Gladiator') 4
# ('Gladiator', 'Æon Flux') 4
# ('Gladiator', "The Emperor's New Groove") 4
# ('Collateral Damage', 'Gladiator') 4
# ('Gladiator', "Legend of the Guardians: The Owls of Ga'Hoole") 4
# ('Elektra', 'Gladiator') 4
# ('Gladiator', 'Pan') 4
# ('Gladiator', 'Point Break') 4
# ('Gladiator', 'Semi-Pro') 4
# ('Gladiator', 'Goosebumps') 5
# ('Gladiator', 'Happy Feet') 5
# ('Avatar', 'Gladiator') 7
# ('Kill Bill: Vol. 1', 'Wrath of the Titans') 4
# ('Bridget Jones: The Edge of Reason', 'Kill Bill: Vol. 1') 4
# ("Charlotte's Web", 'Kill Bill: Vol. 1') 4
# ('Kill Bill: Vol. 1', 'The Postman') 4
# ('Kill Bill: Vol. 1', 'Snake Eyes') 4
# ('Kill Bill: Vol. 1', 'The Rundown') 4
# ('Kill Bill: Vol. 1', 'Warcraft') 4
# ('Kill Bill: Vol. 1', 'The Little Prince') 4
# ('Hellboy II: The Golden Army', 'Kill Bill: Vol. 1') 4
# ('Avatar', 'Kill Bill: Vol. 1') 5
# ('How to Train Your Dragon', 'Kill Bill: Vol. 1') 5
# ('First Knight', 'Kill Bill: Vol. 1') 5
# ('Kill Bill: Vol. 1', 'Prometheus') 6
# ('The Matrix Reloaded', 'Unforgotten') 4
# ('Planet 51', 'Unforgotten') 4
# ('Arthur and the Invisibles', 'Unforgotten') 4
# ('The Man from U.N.C.L.E.', 'Unforgotten') 4
# ('Ice Age: The Meltdown', 'Unforgotten') 4
# ('The Lovers', 'Unforgotten') 4
# ('Men in Black II', 'Unforgotten') 4
# ('Bulletproof Monk', 'Unforgotten') 4
# ('Jurassic World', 'Unforgotten') 5
# ('Eyes Wide Shut', 'Unforgotten') 5
# ('True Lies', 'Unforgotten') 5
# ('Con Air', 'Couples Retreat') 4
# ('Couples Retreat', 'Godzilla Resurgence') 4
# ('Couples Retreat', 'State of Play') 4
# ('2 Guns', 'Couples Retreat') 4
# ('Avatar', 'Couples Retreat') 5
# ('Couples Retreat', 'Total Recall') 7
# ('Gods of Egypt', 'Sin City: A Dame to Kill For') 4
# ('Final Fantasy: The Spirits Within', 'Gods of Egypt') 4
# ('G.I. Joe: The Rise of Cobra', 'Gods of Egypt') 4
# ('Gods of Egypt', 'The Bourne Legacy') 4
# ('Gods of Egypt', 'Wyatt Earp') 4
# ('Driven', 'Gods of Egypt') 4
# ('Absolute Power', 'Gods of Egypt') 4
# ('Gods of Egypt', 'Pan') 4
# ('Avatar', 'Gods of Egypt') 7
# ('Constantine', 'Silent Hill') 4
# ('Constantine', 'Outbreak') 4
# ('Constantine', 'Jurassic World') 4
# ('Constantine', 'Star Trek: Insurrection') 4
# ('Constantine', 'The Hunger Games: Mockingjay - Part 1') 4
# ('Constantine', 'Vertical Limit') 4
# ('Avatar', 'Constantine') 4
# ('Constantine', 'Son of the Mask') 4
# ('Constantine', 'The Hunted') 4
# ('Constantine', 'Starsky & Hutch') 4
# ('Constantine', 'Salt') 4
# ('Constantine', 'Jack Reacher') 5
# ('Constantine', 'Dinner for Schmucks') 5
# ('2 Guns', 'Constantine') 5
# ('Constantine', 'Inkheart') 6
# ('Avengers: Age of Ultron', 'Constantine') 6
# ('The Revenant', 'Zodiac') 4
# ('Speed 2: Cruise Control', 'The Revenant') 4
# ('Cinderella', 'The Revenant') 4
# ('G.I. Joe: Retaliation', 'The Revenant') 4
# ('Pan', 'The Revenant') 4
# ('Dinosaur', 'The Revenant') 4
# ('Congo', 'The Revenant') 5
# ('Dinner for Schmucks', 'The Revenant') 5
# ('Avatar', 'Dinner for Schmucks', 'The Revenant') 4
# ('RED 2', 'The Revenant') 5
# ('Avatar', 'The Revenant') 7
# ('Madagascar', 'The Wolf of Wall Street') 4
# ('Star Trek Beyond', 'The Wolf of Wall Street') 4
# ('The Ring Two', 'The Wolf of Wall Street') 4
# ('Contact', 'The Wolf of Wall Street') 4
# ('Lara Croft: Tomb Raider', 'The Wolf of Wall Street') 4
# ('Alien: Resurrection', 'The Wolf of Wall Street') 4
# ('Inglourious Basterds', 'The Wolf of Wall Street') 5
# ('Shrek the Third', 'The Sentinel') 4
# ('Avatar', 'Shrek the Third', 'The Sentinel') 4
# ('Shrek the Third', 'The Ring Two') 4
# ('Braveheart', 'Shrek the Third') 4
# ('Hercules', 'Shrek the Third') 4
# ('Dragonfly', 'Shrek the Third') 4
# ('Fantasia 2000', 'Shrek the Third') 5
# ('Ghost Rider', 'Shrek the Third') 5
# ('Antz', 'Shrek the Third') 5
# ('Avatar', 'Shrek the Third') 7
# ('Batman Begins', 'Ghost Rider: Spirit of Vengeance') 4
# ('Batman Begins', 'Point Break') 4
# ('Batman Begins', 'World Trade Center') 4
# ('Batman Begins', 'Star Trek Beyond') 4
# ('Batman Begins', 'Deck the Halls') 4
# ('Batman Begins', "Harry Potter and the Sorcerer's Stone") 4
# ('Batman Begins', 'Ronin') 4
# ('Batman Begins', 'X-Men') 4
# ('Batman Begins', 'Pan') 5
# ('Batman Begins', 'Planet of the Apes') 5
# ('Batman Begins', 'Dinosaur') 5
# ('Avatar', 'Batman Begins') 9
# ('Con Air', 'The Horse Whisperer') 4
# ('The Horse Whisperer', 'Total Recall') 4
# ('On Deadly Ground', 'The Horse Whisperer') 4
# ('The Abyss', 'The Horse Whisperer') 4
# ('Captain America: The First Avenger', 'The Horse Whisperer') 4
# ('Death Race', 'The Horse Whisperer') 4
# ('Now You See Me 2', 'The Horse Whisperer') 4
# ('Harry Potter and the Chamber of Secrets', 'The Horse Whisperer') 4
# ('Captain America: The First Avenger', 'Harry Potter and the Chamber of Secrets', 'The Horse Whisperer') 4
# ('Death Race', 'Harry Potter and the Chamber of Secrets', 'The Horse Whisperer') 4
# ('Harry Potter and the Chamber of Secrets', 'Mars Attacks!', 'The Horse Whisperer') 4
# ('Captain America: The First Avenger', 'Death Race', 'Harry Potter and the Chamber of Secrets', 'The Horse Whisperer') 4
# ('Captain America: The First Avenger', 'Harry Potter and the Chamber of Secrets', 'Mars Attacks!', 'The Horse Whisperer') 4
# ('Death Race', 'Harry Potter and the Chamber of Secrets', 'Mars Attacks!', 'The Horse Whisperer') 4
# ('Captain America: The First Avenger', 'Death Race', 'Harry Potter and the Chamber of Secrets', 'Mars Attacks!', 'The Horse Whisperer') 4
# ('Mars Attacks!', 'The Horse Whisperer') 5
# ('Sin City: A Dame to Kill For', 'The Horse Whisperer') 5
# ('Avatar', 'The Horse Whisperer') 7
# ('Grown Ups', 'Shrek Forever After') 4
# ('Grown Ups', 'The Fan') 4
# ('Grown Ups', 'Independence Day') 4
# ('Grown Ups', 'The Twilight Saga: New Moon') 4
# ('Grown Ups', 'War Horse') 4
# ('Grown Ups', 'State of Play') 4
# ('Grown Ups', 'The Spanish Prisoner') 4
# ('Grown Ups', 'Pirates of the Caribbean: On Stranger Tides') 5
# ('Grown Ups', 'Jerry Maguire') 5
# ('Grown Ups', 'Imagine That') 5
# ('Avatar', 'Grown Ups') 9
# ('The Hunger Games: Mockingjay - Part 2', 'The Wolfman') 4
# ('Spy Game', 'The Hunger Games: Mockingjay - Part 2') 4
# ('Red Dragon', 'The Hunger Games: Mockingjay - Part 2') 4
# ('Avatar', 'Red Dragon', 'The Hunger Games: Mockingjay - Part 2') 4
# ('Resident Evil: Apocalypse', 'The Hunger Games: Mockingjay - Part 2') 4
# ("Ocean's Eleven", 'The Hunger Games: Mockingjay - Part 2') 4
# ('Jerry Maguire', 'The Hunger Games: Mockingjay - Part 2') 4
# ('Inkheart', 'The Hunger Games: Mockingjay - Part 2') 4
# ('Con Air', 'The Hunger Games: Mockingjay - Part 2') 4
# ('The Hunger Games: Mockingjay - Part 2', 'The Lord of the Rings: The Fellowship of the Ring') 4
# ('Driven', 'The Hunger Games: Mockingjay - Part 2') 4
# ('The Hunchback of Notre Dame', 'The Hunger Games: Mockingjay - Part 2') 6
# ('Avatar', 'The Hunger Games: Mockingjay - Part 2') 8
# ('Avatar', 'Avatar', 'The Hunger Games: Mockingjay - Part 2') 4
# ('American Reunion', 'Now You See Me') 4
# ('Now You See Me', 'Year One') 4
# ('Now You See Me', 'Pirates of the Caribbean: On Stranger Tides') 4
# ('Now You See Me', 'Shrek') 4
# ('Domestic Disturbance', 'Now You See Me') 4
# ('Now You See Me', 'The Hunger Games') 4
# ('Godzilla Resurgence', 'Now You See Me') 5
# ('Now You See Me', 'Red Tails') 5
# ('Now You See Me', 'The Avengers') 5
# ('Now You See Me', 'Red Tails', 'The Avengers') 4
# ('Avatar', 'Now You See Me') 6
# ('Collateral', 'Saving Private Ryan') 4
# ('Saving Private Ryan', 'The Brothers Grimm') 4
# ('RED 2', 'Saving Private Ryan') 4
# ('How Do You Know', 'Saving Private Ryan') 4
# ('Mars Needs Moms', 'Saving Private Ryan') 4
# ('Saving Private Ryan', 'The Other Guys') 4
# ('Did You Hear About the Morgans?', 'Saving Private Ryan') 4
# ('Saving Private Ryan', 'Sinbad: Legend of the Seven Seas') 4
# ('Saving Private Ryan', 'The Relic') 4
# ('Saving Private Ryan', 'Vanilla Sky') 4
# ('Alice Through the Looking Glass', 'Saving Private Ryan') 5
# ('Catch Me If You Can', 'Saving Private Ryan') 5
# ('Land of the Lost', 'Saving Private Ryan') 5
# ('Payback', 'Saving Private Ryan') 5
# ('Saving Private Ryan', 'The Nutcracker in 3D') 5
# ('Avatar', 'Saving Private Ryan') 6
# ('Clear and Present Danger', 'Me, Myself & Irene') 4
# ('Clear and Present Danger', 'Open Season') 4
# ('Clear and Present Danger', 'Godzilla Resurgence') 4
# ('Clear and Present Danger', 'Sahara') 4
# ('Clear and Present Danger', 'Monsters vs. Aliens') 5
# ('Clear and Present Danger', 'The Avengers') 5
# ('Evita', 'Ice Age: The Meltdown', 'Red Dragon') 4
# ('Avatar', 'Evita', 'Ice Age: The Meltdown', 'Red Dragon') 4
# ('Avatar', 'Evita', 'Red Dragon') 5
# ('Evita', 'The Great Gatsby') 4
# ('Evita', 'The Rundown') 4
# ('Evita', 'Hellboy') 4
# ('Evita', 'Godzilla Resurgence') 4
# ('Evita', 'RoboCop') 4
# ('Evita', 'Mighty Joe Young') 4
# ('Evita', 'Xi you ji zhi: Sun Wukong san da Baigu Jing') 4
# ('Evita', 'Pan') 4
# ('Catch Me If You Can', 'Evita') 5
# ('Evita', 'Ice Age: The Meltdown') 5
# ('Avatar', 'Evita', 'Ice Age: The Meltdown') 4
# ('Avatar', 'Evita') 6
# ('After Earth', 'Domestic Disturbance') 4
# ('Absolute Power', 'After Earth') 4
# ('After Earth', 'Mulan') 4
# ('After Earth', 'The Relic') 4
# ('After Earth', 'Godzilla Resurgence') 4
# ('After Earth', 'The Smurfs 2') 4
# ('After Earth', 'Alexander') 4
# ('After Earth', 'Avengers: Age of Ultron') 4
# ('After Earth', 'Leatherheads') 4
# ('After Earth', 'Non-Stop') 4
# ('After Earth', 'Miss Congeniality 2: Armed and Fabulous') 4
# ('After Earth', 'Cinderella Man') 4
# ('After Earth', 'Almost Famous') 5
# ('After Earth', 'Total Recall') 6
# ('After Earth', 'Avatar') 6
# ('Mars Needs Moms', 'The Matrix Revolutions') 4
# ('Godzilla Resurgence', 'Mars Needs Moms') 4
# ('Avatar', 'Mars Needs Moms') 4
# ('A Good Day to Die Hard', 'Mars Needs Moms') 4
# ('Mars Needs Moms', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Mars Needs Moms', 'Monkeybone') 4
# ('Allegiant', 'Mars Needs Moms') 4
# ('Deadpool', 'Mars Needs Moms') 5
# ('Batman & Robin', 'Captain America: Civil War') 4
# ('Captain America: Civil War', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Avatar', 'Captain America: Civil War', 'The Twilight Saga: Breaking Dawn - Part 2') 6
# ('Captain America: Civil War', 'Oliver Twist') 4
# ('Captain America: Civil War', 'Clash of the Titans') 4
# ('Captain America: Civil War', 'Meet Dave') 4
# ('Captain America: Civil War', 'Syriana') 4
# ('Captain America: Civil War', 'The Brothers Grimm') 4
# ('Captain America: Civil War', 'The Mummy Returns') 5
# ('Captain America: Civil War', 'Pan') 5
# ('Captain America: Civil War', 'Domestic Disturbance') 5
# ('Avatar', 'Captain America: Civil War') 7
# ('I, Frankenstein', 'X-Men: Days of Future Past') 4
# ('Ghostbusters', 'X-Men: Days of Future Past') 4
# ('Godzilla Resurgence', 'X-Men: Days of Future Past') 4
# ('Dinner for Schmucks', 'X-Men: Days of Future Past') 4
# ('Red Dawn', 'X-Men: Days of Future Past') 4
# ('Non-Stop', 'X-Men: Days of Future Past') 4
# ('Alice Through the Looking Glass', 'X-Men: Days of Future Past') 4
# ('Big Hero 6', 'X-Men: Days of Future Past') 4
# ('Creepshow', 'X-Men: Days of Future Past') 4
# ('RoboCop', 'X-Men: Days of Future Past') 4
# ('The Lost World: Jurassic Park', 'X-Men: Days of Future Past') 5
# ('Avatar', 'X-Men: Days of Future Past') 5
# ('Poseidon', 'Spider-Man 2') 4
# ('Poseidon', 'The Fast and the Furious: Tokyo Drift') 4
# ('Pirates of the Caribbean: On Stranger Tides', 'Poseidon') 4
# ('Firewall', 'Poseidon') 4
# ('Poseidon', 'The Last Samurai') 4
# ('Paddington', 'Poseidon') 4
# ('Big Hero 6', 'Poseidon') 4
# ('Avatar', 'Big Hero 6', 'Poseidon') 4
# ('Deck the Halls', 'Poseidon') 5
# ('Poseidon', 'Star Trek: Insurrection') 5
# ('Avatar', 'Poseidon') 6
# ('2 Guns', 'Poseidon') 6
# ('I Am Legend', 'Rango') 4
# ('I Am Legend', 'Syriana') 4
# ('I Am Legend', 'Just Go with It') 4
# ('Daylight', 'I Am Legend') 4
# ('Almost Famous', 'I Am Legend') 4
# ('I Am Legend', 'Scooby-Doo') 4
# ('I Am Legend', 'Sahara') 5
# ('Hall Pass', 'Underworld: Awakening') 4
# ('Hall Pass', 'Resident Evil: Retribution') 4
# ('After Earth', 'Hall Pass', 'Resident Evil: Retribution') 6
# ('Hall Pass', 'Jerry Maguire') 4
# ('After Earth', 'Hall Pass', 'Jerry Maguire') 6
# ('Absolute Power', 'Hall Pass') 4
# ('Absolute Power', 'After Earth', 'Hall Pass') 6
# ('Hall Pass', 'Monsters vs. Aliens') 4
# ('After Earth', 'Hall Pass', 'Monsters vs. Aliens') 6
# ('Hall Pass', 'Mighty Joe Young', "The Devil's Own") 4
# ('After Earth', 'Hall Pass', 'Mighty Joe Young', "The Devil's Own") 6
# ('After Earth', 'Hall Pass', 'Mighty Joe Young') 6
# ('Hall Pass', 'Mulan') 4
# ('After Earth', 'Hall Pass', 'Mulan') 6
# ('Godzilla Resurgence', 'Hall Pass', "The Devil's Own") 4
# ('After Earth', 'Godzilla Resurgence', 'Hall Pass', "The Devil's Own") 6
# ('After Earth', 'Godzilla Resurgence', 'Hall Pass') 6
# ('Hall Pass', 'Just Like Heaven') 4
# ('Collateral', 'Hall Pass') 4
# ('Hall Pass', 'The Ghost and the Darkness') 4
# ('Hall Pass', 'Hercules') 5
# ('Hall Pass', 'Snake Eyes') 5
# ('After Earth', 'Hall Pass') 6
# ('Hall Pass', "The Devil's Own") 6
# ('After Earth', 'Hall Pass', "The Devil's Own") 6
# ('Avatar', 'Hall Pass') 10
# ('Hancock', 'The Pursuit of Happyness') 4
# ('Did You Hear About the Morgans?', 'The Pursuit of Happyness') 4
# ('Pirates of the Caribbean: On Stranger Tides', 'The Pursuit of Happyness') 4
# ('Resident Evil: Afterlife', 'The Pursuit of Happyness') 4
# ('Stealth', 'The Pursuit of Happyness') 4
# ('Deck the Halls', 'The Pursuit of Happyness') 4
# ('The Lord of the Rings: The Two Towers', 'The Pursuit of Happyness') 4
# ('The Pursuit of Happyness', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Stealth', 'The Pursuit of Happyness', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Immortals', 'The Pursuit of Happyness') 4
# ('Avatar', 'The Pursuit of Happyness') 5
# ('Focus', 'Hannibal') 4
# ('Hancock', 'Hannibal') 4
# ('Hannibal', 'Rise of the Planet of the Apes') 4
# ('Hannibal', 'Soldier') 4
# ('Hannibal', 'Monkeybone') 4
# ('Hannibal', 'Ice Age: The Meltdown') 4
# ('Hannibal', 'Harry Potter and the Goblet of Fire') 4
# ('Hannibal', 'The Nutty Professor') 4
# ('Hannibal', 'Teenage Mutant Ninja Turtles') 4
# ('Hannibal', 'The Fast and the Furious') 4
# ('Avatar', 'Hannibal') 8
# ('A Beautiful Mind', 'Rise of the Planet of the Apes') 4
# ('A Beautiful Mind', 'Hotel Transylvania 2') 4
# ('A Beautiful Mind', 'Charlie and the Chocolate Factory') 4
# ('A Beautiful Mind', 'Casino Royale') 4
# ('A Beautiful Mind', 'Garfield') 4
# ('A Beautiful Mind', 'Night at the Museum: Secret of the Tomb') 4
# ('A Beautiful Mind', 'The Spanish Prisoner') 4
# ('A Beautiful Mind', "Ender's Game") 4
# ('A Beautiful Mind', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('A Beautiful Mind', 'Sucker Punch') 4
# ('A Beautiful Mind', 'Life of Pi') 5
# ('A Beautiful Mind', 'Hercules') 5
# ('A Beautiful Mind', 'Avatar', 'Hercules') 4
# ('A Beautiful Mind', 'Avatar') 9
# ('Die Another Day', 'Outbreak') 4
# ('Die Another Day', 'I Am Number Four') 4
# ('Die Another Day', 'I Am Number Four', "Ocean's Eleven") 4
# ('Die Another Day', 'Maleficent') 4
# ('Die Another Day', 'Jack the Giant Slayer') 4
# ('Die Another Day', 'xXx') 4
# ('Die Another Day', 'Just Go with It') 4
# ('Die Another Day', 'The Bourne Identity') 4
# ('Die Another Day', 'The Bourne Legacy') 4
# ('Die Another Day', "Ocean's Eleven", 'The Bourne Legacy') 4
# ('Die Another Day', 'Æon Flux') 4
# ('Die Another Day', "Ocean's Eleven", 'Æon Flux') 4
# ('Die Another Day', 'The Great Gatsby') 4
# ('Die Another Day', 'Night at the Museum: Battle of the Smithsonian') 4
# ('Die Another Day', "Ocean's Eleven") 4
# ('Die Another Day', 'Hotel Transylvania 2', "Ocean's Eleven") 4
# ('Big Hero 6', 'Die Another Day', "Ocean's Eleven") 4
# ('Big Hero 6', 'Die Another Day', 'Hotel Transylvania 2', "Ocean's Eleven") 4
# ('Die Another Day', 'Hotel Transylvania 2') 5
# ('Die Another Day', 'Suicide Squad') 5
# ('Avatar', 'Die Another Day') 5
# ('Big Hero 6', 'Die Another Day') 5
# ('Apollo 13', 'Fantasia 2000') 4
# ('Apollo 13', "Ender's Game") 4
# ('Apollo 13', 'Gangs of New York') 4
# ('Apollo 13', 'The Expendables') 4
# ('Apollo 13', 'Teenage Mutant Ninja Turtles') 4
# ('Apollo 13', 'Casper') 4
# ('Apollo 13', 'Star Wars: Episode VII - The Force Awakens') 4
# ('Apollo 13', 'The Relic') 4
# ('Apollo 13', 'Shrek') 4
# ('Apollo 13', 'Enchanted') 4
# ('Apollo 13', 'The Twilight Saga: Breaking Dawn - Part 2') 6
# ('Apollo 13', 'Avatar') 7
# ('Harry Potter and the Goblet of Fire', 'Spy Game') 4
# ('How to Train Your Dragon', 'Spy Game') 4
# ('Non-Stop', 'Spy Game') 4
# ('Con Air', 'Spy Game') 4
# ('Casper', 'Spy Game') 4
# ('Snake Eyes', 'Spy Game') 4
# ('AVP: Alien vs. Predator', 'Spy Game') 4
# ('Spy Game', 'The Lord of the Rings: The Two Towers') 4
# ('Creepshow', 'Spy Game') 5
# ('Spy Game', 'The Love Guru') 5
# ('Avatar', 'Spy Game') 6
# ('Final Fantasy: The Spirits Within', 'Lilo & Stitch') 4
# ('Final Fantasy: The Spirits Within', 'The Bourne Identity') 4
# ('Did You Hear About the Morgans?', 'Final Fantasy: The Spirits Within') 4
# ('Final Fantasy: The Spirits Within', 'I, Frankenstein') 4
# ('Final Fantasy: The Spirits Within', 'The Lord of the Rings: The Two Towers') 4
# ('Final Fantasy: The Spirits Within', 'The Legend of Tarzan') 4
# ('Final Fantasy: The Spirits Within', 'The Last Legion') 4
# ('Black Mass', 'Final Fantasy: The Spirits Within') 5
# ('Final Fantasy: The Spirits Within', 'RoboCop') 5
# ('Avatar', 'Final Fantasy: The Spirits Within') 7
# ('Final Fantasy: The Spirits Within', 'Iron Man 2') 7
# ('Man on the Moon', 'The Lost World: Jurassic Park') 4
# ('Con Air', 'Man on the Moon') 4
# ('Man on the Moon', 'The Other Guys') 5
# ('Avatar', 'Man on the Moon') 8
# ('Die Hard 2', 'Stuart Little') 4
# ('Burlesque', 'Die Hard 2', 'Stuart Little') 4
# ('Eraser', 'Stuart Little') 4
# ('Mirror Mirror', 'Stuart Little') 4
# ('Stuart Little', 'Turbo') 4
# ('Hidalgo', 'Stuart Little') 4
# ('Daylight', 'Stuart Little') 4
# ('Burlesque', 'Stuart Little') 4
# ('Bicentennial Man', 'Stuart Little') 5
# ('Evan Almighty', 'The Book of Eli') 4
# ('Evan Almighty', 'Eyes Wide Shut') 4
# ('Evan Almighty', 'The Avengers') 4
# ('Chicken Little', 'Evan Almighty') 4
# ('Evan Almighty', 'Failure to Launch') 4
# ('Evan Almighty', 'Instinct') 4
# ('Evan Almighty', "Madagascar 3: Europe's Most Wanted") 4
# ('Evan Almighty', 'On Deadly Ground') 4
# ('Avatar', 'Evan Almighty') 5
# ('Evan Almighty', 'Inglourious Basterds') 5
# ('Astro Boy', 'The Amazing Spider-Man 2') 4
# ('Astro Boy', 'Avatar', 'The Amazing Spider-Man 2') 4
# ('Astro Boy', 'Jumper') 4
# ('Absolute Power', 'Astro Boy') 4
# ('Astro Boy', 'World Trade Center') 4
# ('Astro Boy', 'Cutthroat Island') 4
# ('Astro Boy', 'Harry Potter and the Half-Blood Prince') 4
# ('Astro Boy', 'Underworld: Awakening') 4
# ('Astro Boy', 'Hitch') 4
# ('Astro Boy', 'Catch Me If You Can') 4
# ('Astro Boy', 'The Adventures of Rocky & Bullwinkle') 4
# ('Astro Boy', 'The Lord of the Rings: The Two Towers') 4
# ('Astro Boy', 'Avatar') 5
# ('Cold Mountain', 'Hook') 4
# ('Cold Mountain', 'Fantastic Four') 4
# ('Cold Mountain', 'Star Trek: Insurrection') 4
# ('Cold Mountain', 'Despicable Me 2') 4
# ('Avatar', 'Cold Mountain', 'Despicable Me 2') 4
# ('10,000 B.C.            ', 'Cold Mountain') 4
# ('Cold Mountain', 'Daylight') 5
# ('Cold Mountain', 'The Bourne Identity') 6
# ('Avatar', 'Cold Mountain') 9
# ('National Treasure', 'Rise of the Guardians') 4
# ('National Treasure', 'Stealth') 4
# ('National Treasure', 'Proof of Life') 4
# ('Ice Age: Dawn of the Dinosaurs', 'National Treasure') 4
# ("Dante's Peak", 'National Treasure') 4
# ('National Treasure', 'Surrogates') 4
# ('National Treasure', 'Pan') 4
# ('Avatar', 'National Treasure') 8
# ('Hollywood Homicide', 'Resident Evil: Retribution') 4
# ('Hollywood Homicide', 'The Smurfs 2') 4
# ('Cheaper by the Dozen 2', 'Hollywood Homicide') 4
# ('Hollywood Homicide', 'Star Wars: Episode VII - The Force Awakens') 4
# ('Cinderella Man', 'Hollywood Homicide') 4
# ('Hercules', 'Hollywood Homicide') 4
# ('Hollywood Homicide', 'Just Go with It') 4
# ('Hollywood Homicide', 'Star Wars: Episode III - Revenge of the Sith') 4
# ('Avatar', 'Hollywood Homicide', 'Star Wars: Episode III - Revenge of the Sith') 5
# ('Hollywood Homicide', 'Master and Commander: The Far Side of the World') 4
# ('Hollywood Homicide', 'Jerry Maguire') 5
# ('Hollywood Homicide', 'Syriana') 5
# ('Hollywood Homicide', 'Xi you ji zhi: Sun Wukong san da Baigu Jing') 5
# ('Avatar', 'Hollywood Homicide') 9
# ('Memoirs of a Geisha', 'Night at the Museum: Secret of the Tomb') 4
# ('Insurgent', 'Memoirs of a Geisha') 4
# ('Hitch', 'Memoirs of a Geisha') 4
# ('Dinner for Schmucks', 'Memoirs of a Geisha') 4
# ('Memoirs of a Geisha', 'The Insider') 4
# ('Due Date', 'Memoirs of a Geisha') 4
# ('Fast Five', 'Memoirs of a Geisha') 4
# ('Dreamcatcher', 'Memoirs of a Geisha') 4
# ('Last Man Standing', 'Memoirs of a Geisha') 4
# ('Avatar', 'Memoirs of a Geisha') 5
# ('Life of Pi', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Over the Hedge', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Proof of Life', 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'The Day the Earth Stood Still') 4
# ('Batman & Robin', 'Proof of Life', 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'The Day the Earth Stood Still') 4
# ('Batman & Robin', 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'The Day the Earth Stood Still') 4
# ('Harry Potter and the Chamber of Secrets', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Everest', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Teenage Mutant Ninja Turtles: Out of the Shadows', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Teenage Mutant Ninja Turtles: Out of the Shadows', 'Transformers: Age of Extinction') 4
# ('Batman & Robin', 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'Transformers: Age of Extinction') 4
# ('Mars Attacks!', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 5
# ('Proof of Life', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 5
# ('Batman & Robin', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 5
# ('Batman & Robin', 'Proof of Life', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Batman & Robin', 'Mars Attacks!', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Batman & Robin', 'Mars Attacks!', 'Proof of Life', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 4
# ('Avatar', 'Teenage Mutant Ninja Turtles: Out of the Shadows') 7
# ('Littleman', 'The Legend of Zorro') 4
# ('Indiana Jones and the Kingdom of the Crystal Skull', 'The Legend of Zorro') 4
# ('The Legend of Zorro', 'xXx') 4
# ('Righteous Kill', 'The Legend of Zorro') 4
# ('The Hunger Games: Mockingjay - Part 1', 'The Legend of Zorro') 4
# ('First Knight', 'The Legend of Zorro') 4
# ('Now You See Me 2', 'The Legend of Zorro') 4
# ('Immortals', 'The Legend of Zorro') 4
# ('Hercules', 'The Legend of Zorro') 4
# ('The Fast and the Furious: Tokyo Drift', 'The Legend of Zorro') 5
# ('State of Play', 'The Legend of Zorro') 5
# ('Avatar', 'The Legend of Zorro') 8
# ('World War Z', 'X-Men: Apocalypse') 4
# ('The Legend of Bagger Vance', 'World War Z') 4
# ('Con Air', 'World War Z') 4
# ('The Bourne Legacy', 'World War Z') 4
# ('The Island', 'World War Z') 4
# ('Be Cool', 'World War Z') 4
# ('Barnyard', 'World War Z') 4
# ('The A-Team', 'World War Z') 5
# ('Avatar', 'World War Z') 5
# ('Ghost Rider', 'World War Z') 5
# ('Fantastic Four', 'World War Z') 6
# ('Pearl Harbor', 'Spider-Man') 4
# ('Spider-Man', 'The Scorpion King') 4
# ('Spider-Man', 'The Departed') 4
# ('Spider-Man', 'Warcraft') 4
# ('Braveheart', 'Spider-Man') 4
# ('Death Race', 'Spider-Man') 4
# ('Bullet to the Head', 'Spider-Man') 4
# ('Spider-Man', 'The Adjustment Bureau') 4
# ('Monkeybone', 'Spider-Man') 4
# ('Non-Stop', 'Spider-Man') 4
# ('Spider-Man', 'We Were Soldiers') 5
# ('Avatar', 'Spider-Man') 5
# ('Pan', 'Spider-Man') 5
# ('Enemy of the State', 'Step Brothers') 4
# ('Hotel Transylvania 2', 'Step Brothers') 4
# ('Quantum of Solace', 'Step Brothers') 4
# ('Paddington', 'Step Brothers') 5
# ('Disclosure', 'Step Brothers') 6
# ('Avatar', 'Step Brothers') 7
# ('Assassins', 'Doctor Dolittle') 4
# ('Assassins', 'Catch Me If You Can') 4
# ('A Touch of Frost', 'Assassins') 4
# ('Assassins', 'Snow White and the Huntsman') 4
# ('Assassins', 'Surrogates') 4
# ('Assassins', 'The Patriot') 5
# ('Assassins', 'Avatar') 7
# ('Wreck-It Ralph', 'X-Men: First Class') 4
# ('Transformers: Age of Extinction', 'Wreck-It Ralph') 4
# ('Furious 7', 'Wreck-It Ralph') 4
# ('Battle Los Angeles', 'Wreck-It Ralph') 4
# ('Sin City: A Dame to Kill For', 'Wreck-It Ralph') 4
# ('The Core', 'Wreck-It Ralph') 4
# ('Date Night', 'Wreck-It Ralph') 4
# ('Avatar', 'Wreck-It Ralph') 6
# ('Imagine That', 'Independence Day') 4
# ('Independence Day', 'Now You See Me 2') 4
# ('Independence Day', 'Spanglish') 4
# ('Independence Day', 'The 13th Warrior') 4
# ('Daylight', 'Independence Day') 4
# ('Hotel Transylvania 2', 'Independence Day') 4
# ('Independence Day', 'The Jackal') 5
# ('Independence Day', 'Oz the Great and Powerful') 5
# ('Mad Max: Fury Road', 'Monsters vs. Aliens') 4
# ('Mad Max: Fury Road', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Mad Max: Fury Road', 'The Incredibles') 4
# ('Mad Max: Fury Road', 'Pirates of the Caribbean: On Stranger Tides') 4
# ('Mad Max: Fury Road', 'The Lovely Bones') 4
# ('Mad Max: Fury Road', 'The Sentinel') 4
# ('Mad Max: Fury Road', 'Noah') 4
# ('Avatar', 'Mad Max: Fury Road') 4
# ('Avatar', 'Mad Max: Fury Road', 'The Sentinel') 4
# ('Mad Max: Fury Road', 'The Expendables') 4
# ('Dreamcatcher', 'Mad Max: Fury Road') 4
# ('Cloudy with a Chance of Meatballs 2', 'Hellboy II: The Golden Army') 4
# ('Cloudy with a Chance of Meatballs 2', "Legend of the Guardians: The Owls of Ga'Hoole") 4
# ('Cloudy with a Chance of Meatballs 2', 'Eye See You', "Legend of the Guardians: The Owls of Ga'Hoole") 4
# ('Cloudy with a Chance of Meatballs 2', 'The Avengers') 4
# ('Cloudy with a Chance of Meatballs 2', 'World Trade Center') 4
# ('A Good Day to Die Hard', 'Cloudy with a Chance of Meatballs 2') 4
# ('Cloudy with a Chance of Meatballs 2', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe') 4
# ('Cloudy with a Chance of Meatballs 2', 'Planet of the Apes') 4
# ('Cloudy with a Chance of Meatballs 2', 'Days of Thunder') 4
# ('Cloudy with a Chance of Meatballs 2', 'The Ghost and the Darkness') 4
# ('Avatar', 'Cloudy with a Chance of Meatballs 2') 6
# ('Cloudy with a Chance of Meatballs 2', 'Eye See You') 6
# ("Charlie's Angels", 'Robin Hood') 4
# ('Cinderella', 'Robin Hood') 4
# ('Analyze That', 'Robin Hood') 4
# ('Robin Hood', 'Shutter Island') 4
# ('Robin Hood', 'Teenage Mutant Ninja Turtles') 4
# ('Robin Hood', 'The Legend of Bagger Vance') 4
# ('Jurassic Park III', 'Robin Hood') 4
# ('Robin Hood', 'Rules of Engagement') 4
# ('Bewitched', 'Robin Hood') 4
# ('Me, Myself & Irene', 'Robin Hood') 4
# ('Robin Hood', 'Starsky & Hutch') 4
# ('Enchanted', 'Robin Hood') 6
# ('Avatar', 'Robin Hood') 6
# ('Fantastic Four', 'Robin Hood') 6
# ('Miss Congeniality 2: Armed and Fabulous', 'Tomorrowland') 4
# ('Chicken Little', 'Miss Congeniality 2: Armed and Fabulous') 4
# ('Madagascar', 'Miss Congeniality 2: Armed and Fabulous') 4
# ('Alexander', 'Miss Congeniality 2: Armed and Fabulous') 4
# ('American Gangster', 'Miss Congeniality 2: Armed and Fabulous') 4
# ('Miss Congeniality 2: Armed and Fabulous', 'The Avengers') 5
# ('10,000 B.C.            ', 'Two Brothers') 4
# ('GoldenEye', 'Two Brothers') 4
# ('Avengers: Age of Ultron', 'Two Brothers') 4
# ('Daylight', 'Two Brothers') 4
# ('Captain America: The First Avenger', 'Two Brothers') 4
# ('Days of Thunder', 'Two Brothers') 4
# ('Hostage', 'Two Brothers') 4
# ('On Deadly Ground', 'Two Brothers') 4
# ('Garfield', 'Two Brothers') 4
# ('Jerry Maguire', 'Two Brothers') 5
# ('Robin Hood: Prince of Thieves', 'Up Close & Personal') 4
# ('The Dictator', 'Up Close & Personal') 4
# ('Avatar', 'Up Close & Personal') 4
# ('Cats & Dogs', 'Up Close & Personal') 4
# ('Doctor Dolittle', 'Up Close & Personal') 4
# ('Doctor Dolittle', 'Imagine That', 'Up Close & Personal') 4
# ('Snake Eyes', 'Up Close & Personal') 4
# ('Hercules', 'Up Close & Personal') 4
# ('Imagine That', 'Up Close & Personal') 5
# ('State of Play', 'Up Close & Personal') 5
# ('Everest', 'Up Close & Personal') 5
# ('Burlesque', 'Everest', 'Up Close & Personal') 4
# ('Burlesque', 'Up Close & Personal') 5
# ('Guardians of the Galaxy', 'Up Close & Personal') 5
# ('Total Recall', 'Up Close & Personal') 6
# ('Dinosaur', 'Lady in the Water') 4
# ('Lady in the Water', 'The Patriot') 4
# ('Lady in the Water', 'The Adjustment Bureau') 4
# ('Lady in the Water', 'Underworld: Awakening') 5
# ('Avatar', 'Lady in the Water') 6
# ('San Andreas', 'The Matrix Reloaded') 4
# ('Cutthroat Island', 'San Andreas') 4
# ('San Andreas', 'The Nutcracker in 3D') 4
# ('Night at the Museum: Battle of the Smithsonian', 'San Andreas') 4
# ('2 Guns', 'San Andreas') 4
# ('San Andreas', 'The Avengers') 4
# ('Braveheart', 'San Andreas') 4
# ('San Andreas', 'Stealth') 5
# ('Avatar', 'San Andreas') 9
# ('Changeling', 'Ghost Rider: Spirit of Vengeance') 4
# ('Changeling', 'Wyatt Earp') 4
# ('Changeling', 'Scooby-Doo') 4
# ('Changeling', 'Congo') 4
# ('Changeling', 'Furious 7') 4
# ('Changeling', 'Vertical Limit') 4
# ('Changeling', 'Fight Club') 4
# ('Changeling', 'Fight Club', 'Pan') 4
# ('Alien: Resurrection', 'Changeling') 4
# ('Changeling', 'Firewall') 4
# ('Changeling', 'Firewall', 'Star Wars: Episode III - Revenge of the Sith') 4
# ('Changeling', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Changeling', 'Prince of Persia: The Sands of Time') 4
# ('Changeling', 'The Lord of the Rings: The Two Towers') 4
# ('Changeling', 'Star Wars: Episode III - Revenge of the Sith') 5
# ('Avatar', 'Changeling', 'Star Wars: Episode III - Revenge of the Sith') 5
# ('American Gangster', 'Changeling') 5
# ('Changeling', 'Pan') 5
# ('Changeling', 'Creepshow') 5
# ('Avatar', 'Changeling') 9
# ('Shaft', "The Emperor's New Groove") 4
# ("Ocean's Thirteen", 'Shaft') 4
# ('Shaft', 'Treasure Planet') 4
# ("Harry Potter and the Sorcerer's Stone", 'Shaft') 4
# ('Mighty Joe Young', 'Shaft') 4
# ('AVP: Alien vs. Predator', 'Shaft') 4
# ('Braveheart', 'Shaft') 4
# ('Mirror Mirror', 'Shaft') 4
# ('Due Date', 'Shaft') 4
# ('Shaft', 'The A-Team') 5
# ('Shaft', 'Spanglish') 6
# ('Avatar', 'Shaft') 6
# ('Be Cool', 'Leatherheads') 4
# ('Date Night', 'Leatherheads') 4
# ('Analyze That', 'Leatherheads') 4
# ('Erin Brockovich', 'Leatherheads') 4
# ('Alexander', 'Leatherheads') 4
# ('Leatherheads', 'The Fast and the Furious: Tokyo Drift') 4
# ('Leatherheads', 'Paddington') 4
# ('Catch Me If You Can', 'Leatherheads') 4
# ('Leatherheads', "Ocean's Thirteen") 4
# ('Leatherheads', 'On Deadly Ground') 5
# ('Avatar', 'Leatherheads') 10
# ('Skyfall', 'Thor') 4
# ('Stuck on You', 'Thor') 4
# ('Sabrina, the Teenage Witch            ', 'Thor') 4
# ('Alvin and the Chipmunks', 'Thor') 4
# ('Avatar', 'Thor') 4
# ('Eraser', 'Thor') 4
# ('Thor', 'X-Men 2') 4
# ('Hostage', 'Thor') 5
# ('Clash of the Titans', 'Thor') 5
# ('Bewitched', 'Man on Fire') 4
# ('Man on Fire', 'The Negotiator') 4
# ('Air Force One', 'Man on Fire') 4
# ('Man on Fire', "Pirates of the Caribbean: Dead Man's Chest") 4
# ('300', 'Man on Fire') 4
# ('Man on Fire', 'Oblivion') 4
# ('Man on Fire', 'The Wolfman') 5
# ('Avatar', 'Man on Fire') 5
# ('Man on Fire', 'The Man from U.N.C.L.E.') 6
# ('Australia', 'The Hobbit: An Unexpected Journey') 4
# ('Pirates of the Caribbean: On Stranger Tides', 'The Hobbit: An Unexpected Journey') 4
# ('The Hobbit: An Unexpected Journey', 'Vanilla Sky') 4
# ('The Hobbit: An Unexpected Journey', 'The Twilight Saga: Eclipse', 'Vanilla Sky') 4
# ('Black Mass', 'The Hobbit: An Unexpected Journey') 4
# ('Erin Brockovich', 'The Hobbit: An Unexpected Journey') 4
# ('Last Action Hero', 'The Hobbit: An Unexpected Journey') 4
# ('Mirror Mirror', 'The Hobbit: An Unexpected Journey') 4
# ('The A-Team', 'The Hobbit: An Unexpected Journey') 4
# ('The Hobbit: An Unexpected Journey', 'The Watch') 4
# ('Pan', 'The Hobbit: An Unexpected Journey') 4
# ('Catwoman', 'The Hobbit: An Unexpected Journey') 5
# ('The Hobbit: An Unexpected Journey', 'The Twilight Saga: Eclipse') 6
# ('The Hobbit: An Unexpected Journey', 'World Trade Center') 6
# ('Avatar', 'The Hobbit: An Unexpected Journey') 6
# ('American Sniper', 'Out of Time') 4
# ('American Sniper', 'The Twilight Saga: Eclipse') 4
# ('American Sniper', 'Avatar') 4
# ('American Sniper', 'Australia') 4
# ('American Sniper', 'Congo') 4
# ('American Sniper', 'Maleficent') 4
# ('American Sniper', 'Catch Me If You Can') 4
# ('American Sniper', 'The Hunger Games: Mockingjay - Part 1') 4
# ('American Sniper', 'The Lord of the Rings: The Two Towers') 4
# ('American Sniper', 'Salt') 5
# ('George of the Jungle', 'On Deadly Ground') 4
# ('George of the Jungle', 'Pan') 4
# ('Any Given Sunday', 'George of the Jungle') 4
# ('Con Air', 'George of the Jungle') 5
# ('Avatar', 'George of the Jungle') 6
# ('George of the Jungle', 'The Avengers') 6
# ('Fantasia 2000', 'Kangaroo Jack') 4
# ('Avengers: Age of Ultron', 'Kangaroo Jack') 4
# ('Kangaroo Jack', 'We Were Soldiers') 4
# ('Kangaroo Jack', 'The Thin Red Line') 4
# ('Kangaroo Jack', 'Turbo') 4
# ('Kangaroo Jack', 'Silent Hill') 4
# ('Hook', 'Kangaroo Jack') 4
# ('Kangaroo Jack', 'Man of Steel', 'The Legend of Tarzan') 4
# ('Avatar', 'Kangaroo Jack', 'Man of Steel', 'The Legend of Tarzan') 10
# ('Avatar', 'Kangaroo Jack', 'The Legend of Tarzan') 6
# ('Avatar', 'Avatar', 'Kangaroo Jack', 'The Legend of Tarzan') 4
# ('Kangaroo Jack', 'Space Cowboys') 4
# ('Con Air', 'Kangaroo Jack') 4
# ('Bicentennial Man', 'Kangaroo Jack') 4
# ('Daylight', 'Kangaroo Jack') 5
# ('Kangaroo Jack', 'Man of Steel') 5
# ('Avatar', 'Kangaroo Jack', 'Man of Steel') 11
# ('Avatar', 'Kangaroo Jack') 11
# ('Avatar', 'Avatar', 'Kangaroo Jack') 4
# ("Charlotte's Web", 'The Postman') 4
# ("Charlotte's Web", 'Speed 2: Cruise Control') 4
# ('A Christmas Carol', "Charlotte's Web") 4
# ("Charlotte's Web", 'Sahara') 4
# ("Charlotte's Web", 'Night at the Museum: Battle of the Smithsonian') 4
# ("Charlotte's Web", 'Rise of the Planet of the Apes') 4
# ("Charlotte's Web", 'Resident Evil: Apocalypse') 5
# ("Charlotte's Web", 'Happy Feet') 5
# ('Avatar', "Charlotte's Web") 7
# ('Monsters vs. Aliens', 'The Twilight Saga: New Moon') 4
# ('Sinbad: Legend of the Seven Seas', 'The Twilight Saga: New Moon') 4
# ('Iron Man 2', 'The Twilight Saga: New Moon') 4
# ('The Hunted', 'The Twilight Saga: New Moon') 4
# ('Death Race', 'The Twilight Saga: New Moon') 4
# ('Avatar', 'The Twilight Saga: New Moon') 7
# ('Cheaper by the Dozen 2', 'I, Robot') 4
# ('I, Robot', 'Spanglish') 4
# ('I, Robot', 'The Adjustment Bureau') 4
# ('I, Robot', 'Ninja Assassin') 4
# ('I, Robot', 'The Perfect Storm') 4
# ('Godzilla Resurgence', 'I, Robot') 5
# ('Avatar', 'I, Robot') 7
# ('Ben-Hur', 'X-Men') 4
# ('First Knight', 'X-Men') 4
# ('Point Break', 'X-Men') 4
# ('Dragonfly', 'X-Men') 4
# ("The Emperor's New Groove", 'X-Men') 4
# ('Cats & Dogs', 'X-Men') 4
# ('Deck the Halls', 'X-Men') 4
# ('The Twilight Saga: Breaking Dawn - Part 2', 'X-Men') 4
# ('Lara Croft: Tomb Raider', 'X-Men') 6
# ('Avatar', 'X-Men') 6
# ('Bewitched', 'Evolution') 4
# ('Everest', 'Evolution') 4
# ('Evolution', 'Last Action Hero') 4
# ('Evolution', 'Æon Flux') 4
# ('Alexander', 'Evolution') 4
# ('Evolution', 'The Departed') 4
# ("Dante's Peak", 'Evolution') 4
# ('Evolution', 'RoboCop') 4
# ('Evolution', 'Total Recall') 4
# ('Avatar', 'Evolution') 5
# ('Rollerball', 'The Tuxedo') 4
# ('Hostage', 'Rollerball') 4
# ('Rollerball', 'The Lost World: Jurassic Park') 4
# ('Rango', 'Rollerball') 4
# ('Rollerball', 'Spectre') 4
# ('Avatar', 'Rollerball') 4
# ('Into the Storm', 'Rollerball') 4
# ('Rollerball', "The Emperor's New Groove") 4
# ('Jerry Maguire', 'Rollerball') 4
# ('Pixels', 'Rollerball') 4
# ('Rollerball', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Antz', 'Rollerball') 4
# ('Rollerball', 'Turbo') 5
# ('Rollerball', "The Sorcerer's Apprentice") 5
# ("Ocean's Eleven", 'Rollerball') 5
# ('Eyes Wide Shut', 'Terminator 2: Judgment Day') 4
# ('Terminator 2: Judgment Day', 'Zodiac') 4
# ('Son of the Mask', 'Terminator 2: Judgment Day') 4
# ('Avatar', 'Son of the Mask', 'Terminator 2: Judgment Day') 4
# ('Over the Hedge', 'Terminator 2: Judgment Day') 4
# ('Enemy of the State', 'Terminator 2: Judgment Day') 4
# ('Green Lantern', 'Terminator 2: Judgment Day') 4
# ('Clash of the Titans', 'Terminator 2: Judgment Day') 4
# ('Terminator 2: Judgment Day', 'Underworld: Awakening') 4
# ('Allegiant', 'Terminator 2: Judgment Day') 5
# ('Cinderella Man', 'Terminator 2: Judgment Day') 5
# ('Happy Feet', 'Terminator 2: Judgment Day') 5
# ('Avatar', 'Terminator 2: Judgment Day') 7
# ('Monsters University', 'X-Men 2') 4
# ('Monsters University', 'The Ghost and the Darkness') 4
# ('Monsters University', 'Monsters vs. Aliens') 4
# ('Monsters University', 'The Avengers') 4
# ('Everest', 'Monsters University') 4
# ('Battleship', 'Monsters University') 4
# ('Daylight', 'Monsters University') 4
# ('Green Lantern', 'Monsters University') 5
# ('Monsters University', 'Proof of Life') 5
# ('Avatar', 'Monsters University') 7
# ('Dr. Dolittle 2', 'The Book of Life') 4
# ('Dr. Dolittle 2', 'Fantastic Four') 4
# ('Dr. Dolittle 2', 'Resident Evil: Afterlife') 4
# ('Dr. Dolittle 2', 'Mighty Joe Young') 4
# ('Dr. Dolittle 2', 'Total Recall') 4
# ('Dr. Dolittle 2', 'Meet Dave') 4
# ('Dr. Dolittle 2', 'The Mortal Instruments: City of Bones') 4
# ('Dr. Dolittle 2', 'I Am Number Four') 4
# ('Dr. Dolittle 2', 'On Deadly Ground') 5
# ('Dr. Dolittle 2', 'Godzilla Resurgence') 5
# ('Dr. Dolittle 2', 'Gravity') 5
# ('The Fan', 'The Manchurian Candidate') 4
# ('The Manchurian Candidate', 'X-Men: First Class') 4
# ('Godzilla Resurgence', 'The Manchurian Candidate') 4
# ('Pan', 'The Manchurian Candidate') 4
# ('RED 2', 'The Manchurian Candidate') 4
# ('The Manchurian Candidate', 'The Thin Red Line') 4
# ('The Manchurian Candidate', 'The Twilight Saga: Eclipse') 5
# ('Batman & Robin', 'The Manchurian Candidate') 5
# ('Avatar', 'The Manchurian Candidate') 7
# ('Collateral', 'Life') 4
# ('Life', 'The Scorpion King') 4
# ('Life', "Pirates of the Caribbean: Dead Man's Chest") 4
# ('Dinosaur', 'Life') 4
# ('Life', 'The Man from U.N.C.L.E.') 4
# ('Godzilla Resurgence', 'Life') 4
# ('Life', 'The Lost World: Jurassic Park') 4
# ('Life', 'The Curious Case of Benjamin Button') 4
# ('Avatar', 'Life', 'The Curious Case of Benjamin Button') 4
# ('Life', 'Proof of Life') 4
# ('Life', 'Noah') 4
# ('Four Christmases', 'Life') 4
# ('Life', 'The Book of Eli') 4
# ('Happy Feet', 'Life') 4
# ('Life', 'Pan') 5
# ('Avatar', 'Life') 5
# ('300', 'The Abyss') 4
# ('300', 'Avatar') 4
# ('300', 'Dragonfly') 4
# ('300', 'RED 2') 4
# ('300', 'Insurgent') 4
# ('300', 'We Were Soldiers') 4
# ('300', 'RED 2', 'We Were Soldiers') 4
# ('300', 'Insurgent', 'We Were Soldiers') 4
# ('300', 'Insurgent', 'RED 2', 'We Were Soldiers') 4
# ('300', 'Daylight') 4
# ('300', 'Daylight', 'We Were Soldiers') 4
# ('300', 'The Wolfman') 4
# ('Anchorman 2: The Legend Continues', 'The Legend of Hercules') 4
# ('Goosebumps', 'The Legend of Hercules') 4
# ('2 Guns', 'The Legend of Hercules') 4
# ('Avatar', 'The Legend of Hercules') 4
# ('The Legend of Hercules', 'The Relic') 4
# ('Skyfall', 'The Legend of Hercules') 4
# ('Paddington', 'The Legend of Hercules') 5
# ('Dragonfly', 'The Legend of Hercules') 5
# ('Pan', 'The Legend of Hercules') 6
# ('Outbreak', 'Stepmom') 4
# ('Rush Hour 3', 'Stepmom') 4
# ('Stepmom', 'The Legend of Bagger Vance') 4
# ('Fantasia 2000', 'Stepmom') 4
# ('Ice Age: The Meltdown', 'Stepmom') 4
# ('Avatar', 'Stepmom') 4
# ('Any Given Sunday', 'Stepmom') 4
# ('Stepmom', 'The Little Prince') 5
# ('Analyze That', 'The Terminal') 4
# ('Teenage Mutant Ninja Turtles', 'The Terminal') 4
# ('Reign of Fire', 'The Terminal') 4
# ('Sinbad: Legend of the Seven Seas', 'The Terminal') 4
# ('Avatar', 'The Terminal') 8
# ('Apollo 13', 'G.I. Joe: Retaliation') 4
# ('G.I. Joe: Retaliation', 'The Expendables') 4
# ('G.I. Joe: Retaliation', 'The Boxtrolls') 4
# ('G.I. Joe: Retaliation', 'The Legend of Tarzan') 4
# ('G.I. Joe: Retaliation', 'RED 2') 4
# ('G.I. Joe: Retaliation', 'Monkeybone', 'RED 2') 4
# ('G.I. Joe: Retaliation', "The Devil's Own") 4
# ('Eraser', 'G.I. Joe: Retaliation') 5
# ('G.I. Joe: Retaliation', 'The Twilight Saga: Breaking Dawn - Part 2') 6
# ('Avatar', 'G.I. Joe: Retaliation') 6
# ('G.I. Joe: Retaliation', 'Monkeybone') 7
# ('The Curious Case of Benjamin Button', 'Twister') 4
# ('Analyze That', 'Twister') 4
# ('Analyze That', 'Avatar', 'Twister') 4
# ('The Dictator', 'Twister') 4
# ('Men in Black', 'Twister') 4
# ('Over the Hedge', 'Twister') 4
# ('Daylight', 'Over the Hedge', 'Twister') 4
# ('Anchorman 2: The Legend Continues', 'Over the Hedge', 'Twister') 4
# ('Anchorman 2: The Legend Continues', 'Daylight', 'Over the Hedge', 'Twister') 4
# ('Resident Evil: Afterlife', 'Twister') 4
# ("The Devil's Own", 'Twister') 4
# ('Battle Los Angeles', 'Twister') 5
# ('Daylight', 'Twister') 5
# ('Anchorman 2: The Legend Continues', 'Daylight', 'Twister') 4
# ('The Break-Up', 'Twister') 6
# ('Anchorman 2: The Legend Continues', 'Twister') 7
# ('Avatar', 'Twister') 11
# ('Outbreak', 'The Lion King') 4
# ('The Lion King', 'Transformers: Age of Extinction') 4
# ("The Devil's Own", 'The Lion King') 4
# ('Gigli', 'The Lion King') 4
# ('Robin Hood: Prince of Thieves', 'The Lion King') 4
# ('Avatar', 'The Lion King') 4
# ('Blood Diamond', 'Hard Rain') 4
# ('Blood Diamond', 'Prometheus') 4
# ('Blood Diamond', 'Dinosaur') 5
# ('Blood Diamond', 'The Ghost and the Darkness') 5
# ('Blood Diamond', 'Mulan', 'The Ghost and the Darkness') 4
# ('Blood Diamond', 'Mulan') 6
# ('Avatar', 'Blood Diamond') 12
# ('Just Like Heaven', 'The Expendables 2') 4
# ('Hancock', 'The Expendables 2') 4
# ('Alien: Resurrection', 'The Expendables 2') 4
# ('The Expendables 2', 'The Man from U.N.C.L.E.') 4
# ('The Bourne Identity', 'The Expendables 2') 4
# ('Avatar', 'The Expendables 2') 7
# ('Bullet to the Head', 'The Adventures of Rocky & Bullwinkle') 4
# ('Fantastic Four', 'The Adventures of Rocky & Bullwinkle') 4
# ('Antz', 'The Adventures of Rocky & Bullwinkle') 4
# ('Enchanted', 'The Adventures of Rocky & Bullwinkle') 4
# ('The Adventures of Rocky & Bullwinkle', 'The Avengers') 4
# ('Gangster Squad', 'The Adventures of Rocky & Bullwinkle') 4
# ('The Adventures of Rocky & Bullwinkle', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Analyze That', 'The Adventures of Rocky & Bullwinkle') 4
# ('Avatar', 'The Adventures of Rocky & Bullwinkle') 7
# ('Land of the Lost', 'The Martian') 4
# ('Black Mass', 'Land of the Lost') 4
# ('Land of the Lost', 'Total Recall') 4
# ('Land of the Lost', 'Prince of Persia: The Sands of Time') 4
# ('Land of the Lost', 'The Twilight Saga: Eclipse') 4
# ('Land of the Lost', 'Pan') 4
# ('Land of the Lost', 'The Boxtrolls') 4
# ('Land of the Lost', 'Mars Attacks!') 4
# ('Avatar', 'Land of the Lost') 8
# ('Flags of Our Fathers', 'The Lovely Bones') 4
# ('Avengers: Age of Ultron', 'Flags of Our Fathers') 4
# ('Flags of Our Fathers', 'Inglourious Basterds') 4
# ('Batman Forever', 'Flags of Our Fathers') 4
# ('Fantastic Four', 'Flags of Our Fathers') 4
# ('Flags of Our Fathers', 'Rush Hour 3') 4
# ('Flags of Our Fathers', 'The Avengers') 4
# ('Antz', 'Flags of Our Fathers') 4
# ('Flags of Our Fathers', 'The Boxtrolls') 5
# ('Flags of Our Fathers', "Mr. Popper's Penguins") 5
# ('Avatar', 'Flags of Our Fathers') 6
# ('Fantastic 4: Rise of the Silver Surfer', 'Silent Hill') 4
# ('Die Hard 2', 'Fantastic 4: Rise of the Silver Surfer') 4
# ('Fantastic 4: Rise of the Silver Surfer', 'On Deadly Ground') 4
# ('Batman & Robin', 'Fantastic 4: Rise of the Silver Surfer') 4
# ('Fantastic 4: Rise of the Silver Surfer', 'The Book of Life') 5
# ('Fantastic 4: Rise of the Silver Surfer', 'The Twilight Saga: Breaking Dawn - Part 2') 5
# ('Cats & Dogs: The Revenge of Kitty Galore', 'Fantastic 4: Rise of the Silver Surfer') 5
# ('Fantastic 4: Rise of the Silver Surfer', 'The Martian') 5
# ('The Book of Life', 'Transformers: Revenge of the Fallen') 4
# ('Avatar', 'Transformers: Revenge of the Fallen') 4
# ('Interview with the Vampire: The Vampire Chronicles', 'Transformers: Revenge of the Fallen') 4
# ('The Chronicles of Riddick', 'Transformers: Revenge of the Fallen') 4
# ('The Matrix', 'Transformers: Revenge of the Fallen') 4
# ('The Adjustment Bureau', 'Transformers: Revenge of the Fallen') 4
# ('A Christmas Carol', 'Transformers: Revenge of the Fallen') 4
# ('Casino Royale', 'Transformers: Revenge of the Fallen') 4
# ('The Twilight Saga: Eclipse', 'Transformers: Revenge of the Fallen') 4
# ('Lilo & Stitch', 'Transformers: Revenge of the Fallen') 5
# ('Daylight', 'Transformers: Revenge of the Fallen') 5
# ('How to Train Your Dragon', 'Transformers: Revenge of the Fallen') 6
# ('The Ring Two', 'Zathura: A Space Adventure') 4
# ('The Secret Life of Walter Mitty', 'Zathura: A Space Adventure') 4
# ('RoboCop', 'Zathura: A Space Adventure') 4
# ('Absolute Power', 'Zathura: A Space Adventure') 5
# ('Avatar', 'Zathura: A Space Adventure') 5
# ('Mortdecai', 'X-Men 2') 4
# ('Mortdecai', 'The Core') 4
# ('Mirror Mirror', 'Mortdecai') 4
# ('Mortdecai', 'Trouble with the Curve') 4
# ('Mortdecai', 'The Expendables 3') 4
# ('Garfield', 'Mortdecai') 4
# ('Mortdecai', 'The Patriot') 4
# ('Mortdecai', 'On Deadly Ground') 4
# ('Daylight', 'Mortdecai') 4
# ('Agora', 'Mortdecai') 4
# ('Bridget Jones: The Edge of Reason', 'Mortdecai') 4
# ('Mortdecai', 'The Smurfs 2') 4
# ('Mortdecai', 'Zodiac') 4
# ('Mortdecai', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Mortdecai', 'Under Siege 2: Dark Territory') 4
# ('Journey 2: The Mysterious Island', 'Mortdecai') 5
# ('Casino Royale', 'Mortdecai') 5
# ('Mortdecai', 'Planet 51') 5
# ('Ben-Hur', 'Mortdecai') 5
# ('Blades of Glory', 'The Last Legion') 4
# ('Blades of Glory', 'Goosebumps') 4
# ('Blades of Glory', 'The Nutty Professor') 4
# ('Blades of Glory', 'Chicken Little') 4
# ('Blades of Glory', 'The A-Team') 4
# ('Blades of Glory', 'Godzilla Resurgence') 4
# ('Avatar', 'Blades of Glory') 7
# ('Arthur and the Invisibles', 'Treasure Planet') 4
# ('Treasure Planet', 'X-Men: Apocalypse') 4
# ('Pan', 'Treasure Planet') 4
# ('The A-Team', 'Treasure Planet') 4
# ('The Day the Earth Stood Still', 'Treasure Planet') 4
# ('Skyfall', 'Treasure Planet') 4
# ...
# ('Avatar', 'The Day After Tomorrow') 10
# ('Rush Hour 3', 'Total Recall') 4
# ('Open Season', 'Rush Hour 3') 4
# ('Monkeybone', 'Rush Hour 3') 4
# ('Rush Hour 3', 'The Avengers') 5
# ('Rush Hour 3', 'The Day After Tomorrow') 5
# ('Rush Hour 3', 'The Relic') 6
# ('Avatar', 'Rush Hour 3') 8
# ('Air Force One', 'The Avengers') 4
# ('Air Force One', 'The Curious Case of Benjamin Button') 4
# ('Air Force One', 'The Legend of Bagger Vance') 4
# ('Air Force One', 'Avatar') 4
# ('Air Force One', "Legend of the Guardians: The Owls of Ga'Hoole") 4
# ('Air Force One', 'Jurassic World') 4
# ('Air Force One', 'Mighty Joe Young') 4
# ('Air Force One', 'Enchanted') 4
# ('Air Force One', 'Hellboy') 4
# ('Air Force One', 'Bicentennial Man') 4
# ('Air Force One', 'Pan') 5
# ('A Christmas Carol', 'Total Recall') 4
# ('A Christmas Carol', 'Fantastic Four') 4
# ('A Christmas Carol', 'Fantastic Four', 'Now You See Me 2') 4
# ('A Christmas Carol', 'Now You See Me 2') 4
# ('A Christmas Carol', 'Avatar') 7
# ('Jurassic World', 'The Man from U.N.C.L.E.') 4
# ('The Legend of Tarzan', 'The Man from U.N.C.L.E.') 4
# ('Die Hard 2', 'The Man from U.N.C.L.E.') 4
# ('Driven', 'The Man from U.N.C.L.E.') 4
# ('Analyze That', 'The Man from U.N.C.L.E.') 5
# ('Avatar', 'The Man from U.N.C.L.E.') 5
# ('The Avengers', 'The Man from U.N.C.L.E.') 5
# ('Hercules', 'Master and Commander: The Far Side of the World') 4
# ('Master and Commander: The Far Side of the World', 'Open Season') 4
# ('A Christmas Carol', 'Master and Commander: The Far Side of the World') 4
# ('Master and Commander: The Far Side of the World', 'Total Recall') 5
# ('Avatar', 'Master and Commander: The Far Side of the World') 10
# ('Collateral', 'Resident Evil: Apocalypse') 4
# ('Did You Hear About the Morgans?', 'Resident Evil: Apocalypse') 4
# ('Hercules', 'Resident Evil: Apocalypse') 4
# ('Bicentennial Man', 'Resident Evil: Apocalypse') 4
# ('Catch Me If You Can', 'Resident Evil: Apocalypse') 4
# ('Avatar', 'Resident Evil: Apocalypse') 9
# ('Alexander', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Alexander', 'Total Recall') 4
# ('2 Guns', 'Alexander') 4
# ('Alexander', 'Avatar') 8
# ('Hercules', 'Hotel for Dogs') 4
# ('Godzilla Resurgence', 'Hotel for Dogs') 4
# ('Hotel for Dogs', "Legend of the Guardians: The Owls of Ga'Hoole") 4
# ('Hotel for Dogs', "Legend of the Guardians: The Owls of Ga'Hoole", 'The 13th Warrior') 4
# ('Hotel for Dogs', 'Total Recall') 4
# ('Hotel for Dogs', 'The 13th Warrior') 5
# ('Hotel for Dogs', 'The Legend of Bagger Vance') 5
# ('Fantastic Four', 'Hotel for Dogs') 5
# ('Avatar', 'Hotel for Dogs') 8
# ('Open Season', 'The Secret Life of Walter Mitty') 4
# ('Open Season', 'The Nutty Professor') 4
# ('Eyes Wide Shut', 'Open Season') 5
# ('2 Guns', 'Open Season') 6
# ('Mulan', 'Open Season') 6
# ('Avatar', 'Open Season') 9
# ('Bicentennial Man', 'Die Hard 2') 4
# ('Catch Me If You Can', 'Die Hard 2') 4
# ('Die Hard 2', 'Now You See Me 2') 4
# ('Die Hard 2', 'Resident Evil: Afterlife') 5
# ('Die Hard 2', 'The Legend of Bagger Vance') 5
# ('Die Hard 2', 'The Lord of the Rings: The Two Towers') 6
# ('Avatar', 'Die Hard 2') 11
# ('Fantastic Four', 'Flushed Away') 5
# ('Flushed Away', 'On Deadly Ground') 5
# ('Flushed Away', 'On Deadly Ground', 'The Nutty Professor') 4
# ('Avatar', 'Flushed Away') 6
# ('Flushed Away', 'The Nutty Professor') 6
# ('Mulan', 'State of Play') 4
# ('Fantastic Four', 'State of Play') 5
# ('State of Play', 'The Lord of the Rings: The Two Towers') 5
# ('State of Play', 'Total Recall') 5
# ('Pan', 'State of Play') 8
# ('Avatar', 'State of Play') 9
# ('Jurassic World', 'The Watch') 5
# ('The Legend of Tarzan', 'The Watch') 5
# ('Avatar', 'The Legend of Tarzan', 'The Watch') 5
# ('Avatar', 'The Watch') 11
# ('Enchanted', 'Hellboy II: The Golden Army') 4
# ('Enchanted', 'The Legend of Bagger Vance') 4
# ('Enchanted', 'The Legend of Tarzan') 4
# ('Enchanted', 'Starsky & Hutch') 4
# ('Enchanted', 'Total Recall') 5
# ('Braveheart', 'Enchanted') 5
# ('Avatar', 'Enchanted') 6
# ('Enchanted', 'Godzilla Resurgence') 6
# ('Hellboy', 'The Legend of Tarzan') 4
# ('Hellboy', 'The Fast and the Furious') 4
# ('Daylight', 'Hellboy') 4
# ('Hellboy', 'Pan') 6
# ('Avatar', 'Hellboy') 12
# ('Collateral', 'Total Recall') 4
# ('Collateral', 'The Fast and the Furious') 4
# ('Avatar', 'Collateral') 11
# ('Monkeybone', 'Starsky & Hutch') 4
# ('Mulan', 'Starsky & Hutch') 4
# ('On Deadly Ground', 'Starsky & Hutch') 4
# ('2 Guns', 'Starsky & Hutch') 5
# ('Avatar', 'Starsky & Hutch') 13
# ('Goosebumps', 'Spectre') 4
# ('Avatar', 'Goosebumps') 4
# ('Goosebumps', 'Resident Evil: Afterlife') 4
# ('Goosebumps', 'The Legend of Bagger Vance') 4
# ('Godzilla Resurgence', 'Goosebumps') 4
# ('Hercules', 'The 13th Warrior') 4
# ('Eyes Wide Shut', 'The 13th Warrior') 4
# ('The 13th Warrior', 'The Lord of the Rings: The Two Towers') 4
# ("Legend of the Guardians: The Owls of Ga'Hoole", 'The 13th Warrior') 5
# ('Pan', 'The 13th Warrior') 7
# ('Avatar', 'Pan', 'The 13th Warrior') 4
# ('Avatar', 'The 13th Warrior') 11
# ('Inglourious Basterds', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Inglourious Basterds', 'The Curious Case of Benjamin Button') 4
# ('Avatar', 'Inglourious Basterds', 'The Curious Case of Benjamin Button') 5
# ('Godzilla Resurgence', 'Inglourious Basterds') 4
# ('Inglourious Basterds', 'Jurassic World') 5
# ('Inglourious Basterds', 'The Lord of the Rings: The Two Towers') 5
# ('Avatar', 'Inglourious Basterds') 12
# ('Hellboy II: The Golden Army', 'The Secret Life of Walter Mitty') 5
# ('Fantastic Four', 'Hellboy II: The Golden Army') 5
# ('Avatar', 'Hellboy II: The Golden Army') 8
# ('Analyze That', 'The Nutty Professor') 4
# ('The Legend of Bagger Vance', 'The Nutty Professor') 4
# ('The Lord of the Rings: The Two Towers', 'The Nutty Professor') 4
# ('Avatar', 'The Nutty Professor') 5
# ('Fantastic Four', 'The Nutty Professor') 6
# ('Bicentennial Man', 'Hercules') 4
# ('Avatar', 'Bicentennial Man') 11
# ('Avatar', 'Avatar', 'Bicentennial Man') 4
# ('Mighty Joe Young', 'Mulan') 4
# ('Mighty Joe Young', 'Total Recall') 4
# ('Hercules', 'Mighty Joe Young') 4
# ('Mighty Joe Young', 'Now You See Me 2') 4
# ('Mighty Joe Young', 'The Secret Life of Walter Mitty') 4
# ('Mighty Joe Young', 'The Twilight Saga: Breaking Dawn - Part 2') 5
# ('Braveheart', 'Mighty Joe Young') 5
# ('Godzilla Resurgence', 'Mighty Joe Young') 6
# ('Resident Evil: Afterlife',) 41
# ('Avatar', 'Resident Evil: Afterlife') 4
# ('Godzilla Resurgence', 'Ice Age: The Meltdown') 4
# ('Ice Age: The Meltdown', 'On Deadly Ground') 4
# ('Ice Age: The Meltdown', 'The Legend of Bagger Vance') 4
# ('Catch Me If You Can', 'Ice Age: The Meltdown') 4
# ('Ice Age: The Meltdown', 'The Legend of Tarzan') 5
# ('Avatar', 'Ice Age: The Meltdown') 16
# ('Avatar', 'Avatar', 'Ice Age: The Meltdown') 5
# ('Eyes Wide Shut', 'The Legend of Tarzan') 4
# ('Eyes Wide Shut', 'The Avengers') 4
# ('Eyes Wide Shut', 'Teenage Mutant Ninja Turtles') 4
# ('Driven', 'Eyes Wide Shut') 4
# ('Avatar', 'Driven', 'Eyes Wide Shut') 4
# ('Avatar', 'Eyes Wide Shut') 16
# ('Did You Hear About the Morgans?', 'Fantastic Four') 4
# ('Did You Hear About the Morgans?', 'Spectre') 4
# ('Did You Hear About the Morgans?', 'On Deadly Ground') 4
# ('Did You Hear About the Morgans?', 'The Legend of Tarzan') 4
# ('Did You Hear About the Morgans?', 'Total Recall') 4
# ('Avatar', 'Did You Hear About the Morgans?') 10
# ('Avatar', 'Avatar', 'Did You Hear About the Morgans?') 4
# ('Now You See Me 2', 'Spectre') 4
# ('Now You See Me 2', 'The Avengers') 5
# ('Avatar', 'Now You See Me 2') 9
# ('Jurassic World', 'Monkeybone') 4
# ('Monkeybone', 'The Legend of Bagger Vance') 4
# ('Fantastic Four', 'Monkeybone') 4
# ('Monkeybone', 'The Relic') 5
# ('Monkeybone', 'Teenage Mutant Ninja Turtles') 5
# ('Monkeybone', 'Pan') 5
# ('Avatar', 'Monkeybone') 11
# ('Analyze That', 'The Fast and the Furious') 5
# ('Daylight', 'The Fast and the Furious') 6
# ('The Curious Case of Benjamin Button', 'The Fast and the Furious') 6
# ('Avatar', 'The Fast and the Furious') 8
# ('The Legend of Tarzan', 'The Secret Life of Walter Mitty') 4
# ('Hercules', 'The Secret Life of Walter Mitty') 4
# ('Garfield', 'The Secret Life of Walter Mitty') 4
# ('Avatar', 'The Secret Life of Walter Mitty') 5
# ('2 Guns', 'On Deadly Ground') 4
# ('2 Guns', 'Avatar') 5
# ('2 Guns', 'The Twilight Saga: Breaking Dawn - Part 2') 6
# ('Braveheart', 'Total Recall') 5
# ('Braveheart', 'Pan') 5
# ('Avatar', 'Braveheart') 6
# ('Driven', "Legend of the Guardians: The Owls of Ga'Hoole") 4
# ("Legend of the Guardians: The Owls of Ga'Hoole", 'The Legend of Tarzan') 4
# ("Legend of the Guardians: The Owls of Ga'Hoole", 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ("Legend of the Guardians: The Owls of Ga'Hoole", 'The Avengers') 6
# ('Avatar', "Legend of the Guardians: The Owls of Ga'Hoole") 10
# ('Garfield', 'Jurassic World') 4
# ('Avatar', 'Jurassic World') 11
# ('Mulan', 'The Relic') 4
# ('Mulan', 'Total Recall') 5
# ('Hercules', 'Mulan') 6
# ('Avatar', 'Mulan') 7
# ('Catch Me If You Can', 'On Deadly Ground') 4
# ('Avatar', 'On Deadly Ground') 6
# ('The Twilight Saga: Eclipse', 'Total Recall') 4
# ('Avatar', 'The Twilight Saga: Eclipse') 6
# ('Pan', 'The Twilight Saga: Eclipse') 6
# ('Daylight', 'The Twilight Saga: Eclipse') 7
# ('Fantastic Four', 'The Relic') 4
# ('The Avengers', 'The Relic') 4
# ('Catch Me If You Can', 'The Relic') 4
# ('The Relic', 'Total Recall') 5
# ('The Legend of Tarzan', 'The Relic') 5
# ('The Lord of the Rings: The Two Towers', 'The Relic') 5
# ('Avatar', 'The Relic') 8
# ('Godzilla Resurgence', 'The Curious Case of Benjamin Button') 4
# ('The Curious Case of Benjamin Button', 'The Lord of the Rings: The Two Towers') 4
# ('Avatar', 'The Curious Case of Benjamin Button', 'The Lord of the Rings: The Two Towers') 4
# ('Avatar', 'The Curious Case of Benjamin Button') 16
# ('Avatar', 'Spectre') 6
# ('Hercules', 'Spectre') 8
# ('Daylight', 'Driven') 4
# ('Driven', 'The Legend of Bagger Vance') 4
# ('Driven', 'The Legend of Tarzan') 4
# ('Driven', 'Hercules') 5
# ('Avatar', 'Driven') 6
# ('Fantastic Four', 'Garfield') 4
# ('Garfield', 'The Lord of the Rings: The Two Towers') 4
# ('Garfield', 'The Legend of Bagger Vance') 5
# ('Avatar', 'Garfield') 11
# ('Godzilla Resurgence', 'Teenage Mutant Ninja Turtles') 4
# ('Fantastic Four', 'Teenage Mutant Ninja Turtles') 4
# ('Teenage Mutant Ninja Turtles', 'The Avengers') 5
# ('Pan', 'Teenage Mutant Ninja Turtles') 7
# ('Avatar', 'Teenage Mutant Ninja Turtles') 13
# ('Analyze That', 'The Avengers') 4
# ('Analyze That', 'Daylight') 4
# ('Analyze That', 'Hercules') 6
# ('Analyze That', 'Avatar') 12
# ('Godzilla Resurgence', 'The Legend of Bagger Vance') 4
# ('Avatar', 'The Legend of Bagger Vance') 7
# ('The Legend of Tarzan', 'The Lord of the Rings: The Two Towers') 4
# ('Avatar', 'The Legend of Tarzan', 'The Lord of the Rings: The Two Towers') 4
# ('Godzilla Resurgence', 'The Lord of the Rings: The Two Towers') 5
# ('The Avengers', 'The Lord of the Rings: The Two Towers') 5
# ('Avatar', 'The Lord of the Rings: The Two Towers') 14
# ('Catch Me If You Can', 'Total Recall') 4
# ('Catch Me If You Can', 'Daylight') 4
# ('Avatar', 'Catch Me If You Can') 9
# ('Daylight', 'Total Recall') 4
# ('Daylight', 'Fantastic Four') 4
# ('Daylight', 'The Twilight Saga: Breaking Dawn - Part 2') 4
# ('Avatar', 'Daylight') 10
# ('The Legend of Tarzan', 'The Twilight Saga: Breaking Dawn - Part 2') 5
# ('Avatar', 'The Legend of Tarzan', 'The Twilight Saga: Breaking Dawn - Part 2') 6
# ('Avatar', 'The Twilight Saga: Breaking Dawn - Part 2') 20
# ('Avatar', 'Avatar', 'The Twilight Saga: Breaking Dawn - Part 2') 7
# ('Hercules', 'The Avengers') 4
# ('Avatar', 'Hercules') 15
# ('Fantastic Four', 'Total Recall') 4
# ('The Legend of Tarzan', 'Total Recall') 4
# ('The Avengers', 'Total Recall') 5
# ('Godzilla Resurgence', 'Total Recall') 8
# ('Avatar', 'Total Recall') 8
# ('Godzilla Resurgence', 'The Legend of Tarzan') 6
# ('Avatar', 'Godzilla Resurgence') 16
# ('Fantastic Four', 'Pan') 4
# ('Pan', 'The Avengers') 4
# ('Pan', 'The Legend of Tarzan') 6
# ('Avatar', 'Pan', 'The Legend of Tarzan') 5
# ('Avatar', 'Pan') 21
# ('Avatar', 'Avatar', 'Pan') 8
# ('The Avengers', 'The Legend of Tarzan') 4
# ('Avatar', 'The Legend of Tarzan') 20
# ('Avatar', 'Avatar', 'The Legend of Tarzan') 6
# ('The Avengers',) 62
# ('Avatar', 'The Avengers') 13
# ('Fantastic Four',) 64
# ('Avatar', 'Fantastic Four') 14
# ('Avatar',) 229
# ('Avatar', 'Avatar') 29
# 9076
# {('Killer Elite',): (('Elektra',), 0.25), ('Invictus',): (('Hook',), 0.25), ('The Holiday',): (('Bad Boys II',), 0.25), ('Interstellar', 'The Forbidden Kingdom'): (('Avatar',), 1.0), ('The Forbidden Kingdom', 'The Watch'): (('Interstellar',), 1.0), ('Absolute Power', 'The Forbidden Kingdom'): (('Interstellar',), 1.0), ('Avatar', 'Interstellar'): (('The Forbidden Kingdom',), 0.8), ('Avatar', 'The Forbidden Kingdom'): (('Interstellar',), 0.8), ('Deep Impact', 'Miss Congeniality 2: Armed and Fabulous'): (('The Fast and the Furious: Tokyo Drift', 'The Thin Red Line'), 1.0), ('Deep Impact', 'The Thin Red Line'): (('Miss Congeniality 2: Armed and Fabulous', 'The Fast and the Furious: Tokyo Drift'), 1.0), ('Deep Impact', 'The Fast and the Furious: Tokyo Drift'): (('Miss Congeniality 2: Armed and Fabulous', 'The Thin Red Line'), 0.8), ('Deep Impact', 'Miss Congeniality 2: Armed and Fabulous', 'The Thin Red Line'): (('The Fast and the Furious: Tokyo Drift',), 1.0), ('Deep Impact', 'The Fast and the Furious: Tokyo Drift', 'The Thin Red Line'): (('Miss Congeniality 2: Armed and Fabulous',), 1.0), ('Tears of the Sun',): (('Bewitched',), 0.2), ('The Edge',): (('Avatar',), 0.25), ('Enchanted', 'In the Name of the King: A Dungeon Siege Tale'): (('The Island',), 1.0), ('In the Name of the King: A Dungeon Siege Tale', 'The Island'): (('Enchanted',), 1.0), ('Cliffhanger', 'Jack Reacher'): (('Madagascar', 'Warcraft'), 1.0), ('Cliffhanger', 'Warcraft'): (('Jack Reacher', 'Madagascar'), 1.0), ('Jack Reacher', 'Warcraft'): (('Cliffhanger', 'Madagascar'), 0.8), ('Cliffhanger', 'Madagascar'): (('Jack Reacher', 'Warcraft'), 1.0), ('Cliffhanger', 'Jack Reacher', 'Madagascar'): (('Warcraft',), 1.0), ('Cliffhanger', 'Jack Reacher', 'Warcraft'): (('Madagascar',), 1.0), ('Avatar', 'Did You Hear About the Morgans?'): ((), 0.4), ('Avatar', 'The Great Raid'): (('Did You Hear About the Morgans?',), 0.6666666666666666), ('Did You Hear About the Morgans?', 'The Great Raid'): (('Avatar',), 1.0), ('Sherlock Holmes',): (('Avatar',), 0.23809523809523808), ('Avatar', 'Money Train'): (('The Day After Tomorrow',), 0.6666666666666666), ('Avatar', 'The Day After Tomorrow'): (('Vertical Limit',), 0.4), ('Money Train', 'The Day After Tomorrow'): (('Avatar',), 0.6666666666666666), ('Cinderella', 'Hulk'): (('The American President',), 1.0), ('Cinderella', 'The American President'): (('Hulk',), 0.8), ('Hulk', 'The American President'): (('Cinderella',), 1.0), ('Déjà Vu', 'The Longest Yard'): (("Charlie Wilson's War",), 0.8), ('Déjà Vu', 'Æon Flux'): (('Avatar',), 0.8), ('The Longest Yard', 'Æon Flux'): (('Déjà Vu',), 1.0), ('Muppets Most Wanted', 'The Longest Yard'): (('Déjà Vu',), 1.0), ("Charlie Wilson's War", 'The Longest Yard'): (('Déjà Vu',), 1.0), ('The Family Man', 'Vanilla Sky'): (('X-Men: The Last Stand',), 1.0), ('The Family Man', 'X-Men: The Last Stand'): (("It's Complicated", 'The Italian Job'), 1.0), ('The Family Man', 'The Italian Job'): (("It's Complicated", 'X-Men: The Last Stand'), 1.0), ("It's Complicated", 'The Family Man'): (('The Italian Job', 'X-Men: The Last Stand'), 0.8), ("It's Complicated", 'X-Men: The Last Stand'): (('The Family Man', 'The Italian Job'), 1.0), ("It's Complicated", 'The Family Man', 'X-Men: The Last Stand'): (('The Italian Job',), 1.0), ('The Family Man', 'The Italian Job', 'X-Men: The Last Stand'): (("It's Complicated",), 1.0), ('Inkheart', 'Lara Croft Tomb Raider: The Cradle of Life'): (('The Majestic',), 1.0), ('Inkheart', 'The Majestic'): (('Lara Croft Tomb Raider: The Cradle of Life',), 1.0), ('Lara Croft Tomb Raider: The Cradle of Life', 'The Majestic'): (('Inkheart',), 1.0), ('Despicable Me', 'Munich'): (('The Brothers Grimm',), 0.6666666666666666), ('Despicable Me', 'The Brothers Grimm'): (('Munich',), 1.0), ('Munich', 'The Brothers Grimm'): (('Despicable Me',), 1.0), ('Avatar', 'Epic'): ((), 0.3333333333333333), ('Avatar', 'Hotel Transylvania'): (('Epic',), 0.5), ('Epic', 'Hotel Transylvania'): (('Avatar',), 1.25), ('DragonH ...
# 1319

# %%
rekomendasi=[]
for x,y in rules.items():
  rekom=[]
  rekom.append(x)
  rekom.append(y[0])
  rekom.append(y[1])

  rekomendasi.append(rekom)
  rules_df=pd.DataFrame(rekomendasi,columns=['Movie','Rekomendasi','Confidence'])
rules_df.head()
# Out:
#                                    Movie      Rekomendasi  Confidence
# 0                        (Killer Elite,)       (Elektra,)        0.25
# 1                            (Invictus,)          (Hook,)        0.25
# 2                         (The Holiday,)   (Bad Boys II,)        0.25
# 3  (Interstellar, The Forbidden Kingdom)        (Avatar,)        1.00
# 4     (The Forbidden Kingdom, The Watch)  (Interstellar,)        1.00

# %%
df=pd.DataFrame(userRiwayat)
df['Items'] = df[df.columns[:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
)
df.drop(df.columns[0:5],axis=1)

def support_count(rhs):  
  count=0
  rhs1=set(str(sup))
  
  for j in df['Items']:
    j=set(j)
    if(rhs1.issubset(j)):
      count=count+1
      return count
support=[]
for i in rules_df['Rekomendasi']:
    a=support_count(i)
    support.append(a/len(df)) #ims
rules_df['support']=support

# %%
rules_df['lift']=rules_df['Confidence']/rules_df['support']

# %%
rules_df.head()
# Out:
#                                    Movie      Rekomendasi  ...  support    lift
# 0                        (Killer Elite,)       (Elektra,)  ...    0.001   250.0
# 1                            (Invictus,)          (Hook,)  ...    0.001   250.0
# 2                         (The Holiday,)   (Bad Boys II,)  ...    0.001   250.0
# 3  (Interstellar, The Forbidden Kingdom)        (Avatar,)  ...    0.001  1000.0
# 4     (The Forbidden Kingdom, The Watch)  (Interstellar,)  ...    0.001  1000.0
#
# [5 rows x 5 columns]
